# %%
import sys, os
import tempfile
import numpy as np
import matplotlib.pyplot as plt
from qcodes import Parameter, DelegateParameter, initialise_or_create_database_at, load_or_create_experiment, load_by_id
# %matplotlib notebook

# Let's create a dummy qcodes database
db_path = os.path.join(tempfile.gettempdir(),'test.db')
initialise_or_create_database_at(db_path)
experiment = load_or_create_experiment(experiment_name='test',sample_name='no sample')
# Out:
# Logging hadn't been started.
# Activating auto-logging. Current session state plus future input saved.
# Filename       : C:\Users\manip.batm\.qcodes\logs\command_history.log
# Mode           : append
# Output logging : True
# Raw input log  : False
# Timestamping   : True
# State          : active
# Qcodes Logfile : C:\Users\manip.batm\.qcodes\logs\230308-7040-qcodes.log

# %%
import qube
from qube.layout.gds import LayoutGDS, ConfigShapes
layout = LayoutGDS(
    gdspath=os.path.join('gds','AB.gds'),
    content=None,
#     gdsconfig=ConfigShapes(os.path.join('gds','AB.ini'))
)
# layout.apply_config()
# layout.plot()

# %%
from cycler import cycler
v = layout.view
fig, ax = plt.subplots(1)
colormap = plt.get_cmap('nipy_spectral')
colors = [colormap(i) for i in np.linspace(0, 1, len(v.elements))]
ax.set_prop_cycle(cycler('color', colors))
for si in v.shapes:
    ax.fill(si.get_x(), si.get_y(), label=si.name)
for ti in v.texts:
    ax.text(ti.get_x(), ti.get_y(), ti.label)
ax.legend(loc='upper right')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
layout = LayoutGDS(
    gdspath=os.path.join('gds','AB.gds'),
    content=None,
    gdsconfig=ConfigShapes(os.path.join('gds','AB.ini'))
)
layout.plot()
# Out:
# <img src="data:image/png;base64,..." width="800">
# (<Figure size 800x400 with 1 Axes>, <Axes: >)
